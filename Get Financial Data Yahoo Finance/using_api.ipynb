# %% [markdown]
# # Libraries

# %%
from yahooquery import Ticker
import requests
import json
import yfinance as yf

# Guide to do it with webscraping.
# https://www.scrapehero.com/how-to-scrape-yahoo-finance-data-using-python/
# https://towardsdatascience.com/web-scraping-yahoo-finance-477fe3daa852

# %% [markdown]
# # API

# %%
# Find ticker symbol by company name.
def ticker(company_name):
    yfinance = "https://query2.finance.yahoo.com/v1/finance/search"
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'
    params = {"q": company_name, "quotes_count": 1, "country": "United States"}

    res = requests.get(url=yfinance, params=params, headers={'User-Agent': user_agent})
    data = res.json()

    company_code = data['quotes'][0]['symbol']
    return company_code

partial_name = input("Enter partial company name: ")
stock_info = ticker(partial_name)
print(stock_info)
# Out:
# KO

# %%
GetFacebookInformation = yf.Ticker("KO")

# display Company Sector
print("Company Sector : ", GetFacebookInformation.info['sector'])

# display Price Earnings Ratio
print("Price Earnings Ratio : ", GetFacebookInformation.info['trailingPE'])

# display Company Beta
print(" Company Beta : ", GetFacebookInformation.info['beta'])
# Out:
# Company Sector :  Consumer Defensive
# Price Earnings Ratio :  28.118422
#  Company Beta :  0.546798

# %%
# Get income statement data for KO
ticker = Ticker("KO")
income_statement = ticker.income_statement()
income_statement
# Out:
#          asOfDate periodType currencyCode  BasicAverageShares  BasicEPS
# symbol
# KO     2019-12-31        12M          USD        4.276000e+09      2.09  \
# KO     2020-12-31        12M          USD        4.295000e+09      1.80
# KO     2021-12-31        12M          USD        4.315000e+09      2.26
# KO     2022-12-31        12M          USD        4.328000e+09      2.20
# KO     2022-12-31        TTM          USD                 NaN       NaN
# KO     2023-03-31        TTM          USD                 NaN       NaN
#
#         CostOfRevenue  DilutedAverageShares  DilutedEPS
# symbol
# KO       1.461900e+10          4.314000e+09        2.07  \
# KO       1.343300e+10          4.323000e+09        1.79
# KO       1.535700e+10          4.340000e+09        2.25
# KO       1.800000e+10          4.350000e+09        2.19
# KO       1.800000e+10                   NaN         NaN
# KO       1.822600e+10                   NaN         NaN
#
#         DilutedNIAvailtoComStockholders          EBIT  ...
# symbol                                                 ...
# KO                         8.920000e+09  1.173200e+10  ...  \
# KO                         7.747000e+09  1.118600e+10  ...
# KO                         9.771000e+09  1.402200e+10  ...
# KO                         9.542000e+09  1.256800e+10  ...
# KO                         9.542000e+09  1.256800e+10  ...
# KO                         9.868000e+09  1.335300e+10  ...
#
#         SellingGeneralAndAdministration  SpecialIncomeCharges
# symbol
# KO                         1.210300e+10         -1.830000e+08  \
# KO                         9.731000e+09         -7.280000e+08
# KO                         1.214400e+10         -7.310000e+08
# KO                         1.288000e+10         -1.139000e+09
# KO                         7.442000e+09         -1.139000e+09
# KO                         7.497000e+09                   NaN
#
#         TaxEffectOfUnusualItems  TaxProvision  TaxRateForCalcs  TotalExpenses
# symbol
# KO                 0.000000e+00  1.801000e+09          0.16700   2.718000e+10  \
# KO                 0.000000e+00  1.981000e+09          0.20300   2.401700e+10
# KO                 0.000000e+00  2.621000e+09          0.21100   2.834700e+10
# KO                 0.000000e+00  2.115000e+09          0.18100   3.209500e+10
# KO                -2.061590e+08  2.115000e+09          0.18100   3.095600e+10
# KO                -2.216603e+08  2.390000e+09          0.19461   3.148300e+10
#
#         TotalOperatingIncomeAsReported  TotalRevenue  TotalUnusualItems
# symbol
# KO                        1.008600e+10  3.726600e+10      -1.830000e+08  \
# KO                        8.997000e+09  3.301400e+10      -7.280000e+08
# KO                        1.030800e+10  3.865500e+10      -7.310000e+08
# KO                        1.090900e+10  4.300400e+10      -1.139000e+09
# KO                        1.090900e+10  4.300400e+10      -1.139000e+09
# KO                        1.087100e+10  4.349300e+10      -1.139000e+09
#
#         TotalUnusualItemsExcludingGoodwill
# symbol
# KO                           -1.830000e+08
# KO                           -7.280000e+08
# KO                           -7.310000e+08
# KO                           -1.139000e+09
# KO                           -1.139000e+09
# KO                           -1.139000e+09
#
# [6 rows x 55 columns]

# %%
# Get quarterly income statement data for KO
quarterly_income_statement = ticker.income_statement(frequency='q')
quarterly_income_statement
# Out:
#          asOfDate periodType currencyCode  BasicAverageShares  BasicEPS
# symbol
# KO     2022-03-31         3M          USD        4.332000e+09      0.64  \
# KO     2022-06-30         3M          USD        4.331000e+09      0.44
# KO     2022-09-30         3M          USD        4.325000e+09      0.65
# KO     2022-12-31         3M          USD        4.326000e+09      0.47
# KO     2022-12-31        TTM          USD                 NaN       NaN
# KO     2023-03-31         3M          USD        4.326000e+09      0.72
# KO     2023-03-31        TTM          USD                 NaN       NaN
#
#         CostOfRevenue  DilutedAverageShares  DilutedEPS
# symbol
# KO       4.091000e+09          4.357000e+09        0.64  \
# KO       4.830000e+09          4.353000e+09        0.44
# KO       4.566000e+09          4.346000e+09        0.65
# KO       4.513000e+09          4.347000e+09        0.47
# KO       1.800000e+10                   NaN         NaN
# KO       4.317000e+09          4.345000e+09        0.72
# KO       1.822600e+10                   NaN         NaN
#
#         DilutedNIAvailtoComStockholders          EBIT  ...
# symbol                                                 ...
# KO                         2.781000e+09  3.640000e+09  ...  \
# KO                         1.905000e+09  2.482000e+09  ...
# KO                         2.825000e+09  3.642000e+09  ...
# KO                         2.031000e+09  2.804000e+09  ...
# KO                         9.542000e+09  1.256800e+10  ...
# KO                         3.107000e+09  4.425000e+09  ...
# KO                         9.868000e+09  1.335300e+10  ...
#
#         SellingGeneralAndAdministration  SpecialIncomeCharges
# symbol
# KO                         2.967000e+09         -1.800000e+07  \
# KO                         3.203000e+09         -9.320000e+08
# KO                         3.279000e+09         -1.040000e+08
# KO                         3.431000e+09         -8.800000e+07
# KO                         7.442000e+09         -1.139000e+09
# KO                         3.185000e+09                   NaN
# KO                         7.497000e+09                   NaN
#
#         TaxEffectOfUnusualItems  TaxProvision  TaxRateForCalcs  TotalExpenses
# symbol
# KO                 0.000000e+00  6.650000e+08          0.19200   7.086000e+09  \
# KO                 0.000000e+00  3.840000e+08          0.16800   8.984000e+09
# KO                 0.000000e+00  6.220000e+08          0.18100   7.975000e+09
# KO                 0.000000e+00  4.440000e+08          0.17700   8.050000e+09
# KO                -2.061590e+08  2.115000e+09          0.18100   3.095600e+10
# KO                 0.000000e+00  9.400000e+08          0.23200   7.613000e+09
# KO                -2.216603e+08  2.390000e+09          0.19461   3.148300e+10
#
#         TotalOperatingIncomeAsReported  TotalRevenue  TotalUnusualItems
# symbol
# KO                        3.405000e+09  1.049100e+10      -1.800000e+07  \
# KO                        2.341000e+09  1.132500e+10      -9.320000e+08
# KO                        3.088000e+09  1.106300e+10      -1.040000e+08
# KO                        2.075000e+09  1.012500e+10      -8.800000e+07
# KO                        1.090900e+10  4.300400e+10      -1.139000e+09
# KO                        3.367000e+09  1.098000e+10                NaN
# KO                        1.087100e+10  4.349300e+10      -1.139000e+09
#
#         TotalUnusualItemsExcludingGoodwill
# symbol
# KO                           -1.800000e+07
# KO                           -9.320000e+08
# KO                           -1.040000e+08
# KO                           -8.800000e+07
# KO                           -1.139000e+09
# KO                                     NaN
# KO                           -1.139000e+09
#
# [7 rows x 53 columns]
